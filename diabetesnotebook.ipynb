# %%
#importing of libraries and reading the data from a csv file
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_87d96f92436a4eba9a1c96c47852673d = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='Qp_x-bfQDFp6ax9_4_XCpkReyzhWioL8cSUaaGDkT7wc',
    ibm_auth_endpoint="https://iam.eu-gb.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_87d96f92436a4eba9a1c96c47852673d.get_object(Bucket='diabetes-donotdelete-pr-xizvu6axvj7wsy',Key='dd.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

# If you are reading an Excel file into a pandas DataFrame, replace `read_csv` by `read_excel` in the next statement.
dataset = pd.read_csv(body)

# %%
#accessing required columns from the entire datasets that are independent

x1=dataset.iloc[:50000,2:5]
x2=dataset.iloc[:50000,8]
x3=dataset.iloc[:50000,26:-1]

# %%
#appending all the splitted datasets into one dataset
x4=pd.concat([x1,x2],axis=1)
x=pd.concat([x4,x3],axis=1)

# %%
x.head()
# Out:
#               race  gender      age         medical_specialty acarbose  \
# 0        Caucasian  Female   [0-10)  Pediatrics-Endocrinology       No
# 1        Caucasian  Female  [10-20)                         ?       No
# 2  AfricanAmerican  Female  [20-30)                         ?       No
# 3        Caucasian    Male  [30-40)                         ?       No
# 4        Caucasian    Male  [40-50)                         ?       No
#
#   miglitol troglitazone tolazamide examide citoglipton insulin  \
# 0       No           No         No      No          No      No
# 1       No           No         No      No          No      Up
# 2       No           No         No      No          No      No
# 3       No           No         No      No          No      Up
# 4       No           No         No      No          No  Steady
#
#   glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# 0                  No                  No                       No
# ...

# %%
#accessing the dependent values from the dataset
y=dataset.iloc[:50000,-1:]

# %%
#replacing the missing values with miss
x=x.replace('?','miss')

# %%
#finding the most races occuring in the datasets
x.groupby('race').size().sort_values(ascending=False)
# Out:
# race
# Caucasian          35711
# AfricanAmerican    11140
# miss                1257
# Hispanic            1019
# Other                610
# Asian                263
# dtype: int64

# %%
#creating a duplicate dataframes
x5=x

# %%
#adjusting the least occurred races into one category called as others
x5=x5.replace(['miss','Hispanic','Other','Asian'],'Others')

# %%
#creating a duplicate of dataframe modified
x6=x5

# %%
#adjusting the least occurred medical_specialty into one category called as others

top=['InternalMedicine','Family/GeneralPractice','Cardiology','Emergency/Trauma']
x6.loc[~x6.medical_specialty.isin(top),'medical_specialty']='Others'

# %%
x6
# Out:
#                   race  gender       age       medical_specialty acarbose  \
# 0            Caucasian  Female    [0-10)                  Others       No
# 1            Caucasian  Female   [10-20)                  Others       No
# 2      AfricanAmerican  Female   [20-30)                  Others       No
# 3            Caucasian    Male   [30-40)                  Others       No
# 4            Caucasian    Male   [40-50)                  Others       No
# 5            Caucasian    Male   [50-60)                  Others       No
# 6            Caucasian    Male   [60-70)                  Others       No
# 7            Caucasian    Male   [70-80)                  Others       No
# 8            Caucasian  Female   [80-90)                  Others       No
# 9            Caucasian  Female  [90-100)        InternalMedicine       No
# 10     AfricanAmerican  Female   [40-50)                  Others       No
# 11     AfricanAmerican    Male   [60-70)                  Others       No
# ...

# %%
#droping some unimportant columns
x6.drop('examide',axis=1,inplace=True)
x6.drop('citoglipton',axis=1,inplace=True)
x6.drop('glimepiride-pioglitazone',axis=1,inplace=True)
x6.drop('metformin-rosiglitazone',axis=1,inplace=True)
x6.drop('metformin-pioglitazone',axis=1,inplace=True)

# %%
x6
# Out:
#                   race  gender       age       medical_specialty acarbose  \
# 0            Caucasian  Female    [0-10)                  Others       No
# 1            Caucasian  Female   [10-20)                  Others       No
# 2      AfricanAmerican  Female   [20-30)                  Others       No
# 3            Caucasian    Male   [30-40)                  Others       No
# 4            Caucasian    Male   [40-50)                  Others       No
# 5            Caucasian    Male   [50-60)                  Others       No
# 6            Caucasian    Male   [60-70)                  Others       No
# 7            Caucasian    Male   [70-80)                  Others       No
# 8            Caucasian  Female   [80-90)                  Others       No
# 9            Caucasian  Female  [90-100)        InternalMedicine       No
# 10     AfricanAmerican  Female   [40-50)                  Others       No
# 11     AfricanAmerican    Male   [60-70)                  Others       No
# ...

# %%
x7=x6.iloc[:,:].values
y1=y
x7
# Out:
# array([['Caucasian', 'Female', '[0-10)', ..., 'No', 'No', 'No'],
#        ['Caucasian', 'Female', '[10-20)', ..., 'No', 'Ch', 'Yes'],
#        ['AfricanAmerican', 'Female', '[20-30)', ..., 'No', 'No', 'Yes'],
#        ...,
#        ['Caucasian', 'Female', '[60-70)', ..., 'No', 'No', 'Yes'],
#        ['Caucasian', 'Male', '[70-80)', ..., 'No', 'No', 'Yes'],
#        ['Caucasian', 'Male', '[70-80)', ..., 'No', 'Ch', 'Yes']],
#       dtype=object)

# %%
#giving average specified values for ranges of age

age_fixed={'[0-10)':5,
           '[10-20)':15,
           '[20-30)':25,
           '[30-40)':35,
           '[40-50)':45,
           '[50-60)':55,
           '[60-70)':65,
           '[70-80)':75,
           '[80-90)':85,
           '[90-100)':95
            }

x8=x6
x8['age_id']=x8.age.replace(age_fixed)
x8.drop('age',axis=1,inplace=True)
x8
# Out:
#                   race  gender       medical_specialty acarbose miglitol  \
# 0            Caucasian  Female                  Others       No       No
# 1            Caucasian  Female                  Others       No       No
# 2      AfricanAmerican  Female                  Others       No       No
# 3            Caucasian    Male                  Others       No       No
# 4            Caucasian    Male                  Others       No       No
# 5            Caucasian    Male                  Others       No       No
# 6            Caucasian    Male                  Others       No       No
# 7            Caucasian    Male                  Others       No       No
# 8            Caucasian  Female                  Others       No       No
# 9            Caucasian  Female        InternalMedicine       No       No
# 10     AfricanAmerican  Female                  Others       No       No
# 11     AfricanAmerican    Male                  Others       No       No
# ...

# %%
#duplicate dataset after age conversion
x9=x8

# %%
#converting independent data into values
x8=x8.iloc[:,:].values

# %%
#label encoding for independent datacolumns

from sklearn.preprocessing import LabelEncoder
labelx=LabelEncoder()

x8[:,0]=labelx.fit_transform(x8[:,0])
x8[:,1]=labelx.fit_transform(x8[:,1])
x8[:,2]=labelx.fit_transform(x8[:,2])
x8[:,3]=labelx.fit_transform(x8[:,3])
x8[:,4]=labelx.fit_transform(x8[:,4])
x8[:,5]=labelx.fit_transform(x8[:,5])
x8[:,6]=labelx.fit_transform(x8[:,6])
x8[:,7]=labelx.fit_transform(x8[:,7])
x8[:,8]=labelx.fit_transform(x8[:,8])
x8[:,9]=labelx.fit_transform(x8[:,9])
x8[:,10]=labelx.fit_transform(x8[:,10])
x8[:,11]=labelx.fit_transform(x8[:,11])
x8[:,12]=labelx.fit_transform(x8[:,12])
x8[:,13]=labelx.fit_transform(x8[:,13])
x8[:,14]=labelx.fit_transform(x8[:,14])
x8[:,15]=labelx.fit_transform(x8[:,15])
x8[:,16]=labelx.fit_transform(x8[:,16])
x8[:,17]=labelx.fit_transform(x8[:,17])
x8[:,18]=labelx.fit_transform(x8[:,18])
x8[:,19]=labelx.fit_transform(x8[:,19])
x8[:,20]=labelx.fit_transform(x8[:,20])
x8[:,21]=labelx.fit_transform(x8[:,21])
x8[:,22]=labelx.fit_transform(x8[:,22])
x8[:,23]=labelx.fit_transform(x8[:,23])
x8[:,24]=labelx.fit_transform(x8[:,24])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-4f483ea7ac7a> in <module>
#      17 x8[:,11]=labelx.fit_transform(x8[:,11])
#      18 x8[:,12]=labelx.fit_transform(x8[:,12])
# ---> 19 x8[:,13]=labelx.fit_transform(x8[:,13])
#      20 x8[:,14]=labelx.fit_transform(x8[:,14])
#      21 x8[:,15]=labelx.fit_transform(x8[:,15])
#
# IndexError: index 13 is out of bounds for axis 1 with size 13

# %%
y3=y
y3=y3.replace('>30','YES')
y3=y3.replace('<30','YES')
y4=y3.iloc[:,:].values
y4

# %%
#label encoding for dependent variable
from sklearn.preprocessing import LabelEncoder
labely=LabelEncoder()

y4[:,0]=labely.fit_transform(y4[:,0])

# %%
#converting int values to float
y23=[float(i) for i in y4]

# %%
#splitting of test sets and train sets 

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x8,y23,test_size=0.2 ,random_state=0)

# %%
#applying logistic regression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(xtrain,ytrain)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#prediction of logistic regression 
ypred=lr.predict(xtest)
ypred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#finding the accuracy for the logistic regression
from sklearn.metrics import accuracy_score
accuracy_score(ytest,ypred)
# Out:
# 0.5347

# %%
#applying Decision Trees and predicting the output

from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion='entropy',random_state=0)
dt.fit(xtrain,ytrain)
ypreddt=dt.predict(xtest)
ypreddt
# Out:
# array([0., 1., 0., ..., 0., 0., 1.])

# %%
#finding the accuracy for the  Decisiontree
from sklearn.metrics import accuracy_score
accuracy_score(ytest,ypreddt)
# Out:
# 0.5489

# %%
#applying KNN for the datasets and predicting the output

from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=100,metric='euclidean',p=2)
knn.fit(xtrain,ytrain)
ypredknn=knn.predict(xtest)
ypredknn
# Out:
# array([0., 1., 0., ..., 0., 0., 0.])

# %%
#finding the accuracy for the selected model
from sklearn.metrics import accuracy_score
accuracy_score(ytest,ypredknn)
# Out:
# 0.5519

# %%
#applying Random Forest and predicting the output 

from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(criterion='entropy',random_state=0,n_estimators=20)
rf.fit(xtrain,ytrain)
ypredrf=rf.predict(xtest)
ypredrf
# Out:
# array([0., 1., 0., ..., 0., 0., 1.])

# %%
#finding the accuracy for the selected model

from sklearn.metrics import accuracy_score
accuracy_score(ytest,ypredrf)
# Out:
# 0.552

# %%
#applying the naive bais and fitting it
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(xtrain,ytrain)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
#predicting the selecting model
ypred3=nb.predict(xtest)

# %%
#accuracy predict for the selected model
from sklearn.metrics import accuracy_score
accuracy_score(ytest,ypred3)
# Out:
# 0.5411

# %%
#applying SVM for the dataset
from sklearn.svm  import SVC
sv=SVC(kernel='linear')
sv.fit(xtrain,ytrain)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
#predicting the output for the selected model
ypred1=sv.predict(xtest)
ypred1
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#predicting the accuracy score for the selected model
from sklearn.metrics import accuracy_score
accuracy_score(ytest,ypred1)
# Out:
# 0.5409

# %%
#importing library that is used for deploying the web application
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %%
#credentials required for giving access
cred={
  "apikey": "QEPWKPShi10cnLdmF8rJPs2Geej8kCgpVvhiM1-bbAaa",
  "iam_apikey_description": "Auto-generated for key f0ca7c04-d5b8-49c5-9cfc-08e66b8e1d01",
  "iam_apikey_name": "Service credentials-1",
  "iam_role_crn": "crn:v1:bluemix:public:iam::::serviceRole:Writer",
  "iam_serviceid_crn": "crn:v1:bluemix:public:iam-identity::a/8755731498594db09c059fedf707922b::serviceid:ServiceId-4dcc5c87-0c2d-4aab-8f6c-7ce76b1560fd",
  "instance_id": "6e91cd73-52bd-48bb-8f77-247556f30e9d",
  "url": "https://eu-gb.ml.cloud.ibm.com"
}

# %%
#creating an instance for the watsonmachinelearning
client=WatsonMachineLearningAPIClient(cred)

# %%
#properties of the model that we are building
modelprop={
    client.repository.ModelMetaNames.AUTHOR_NAME:"rahulpro",
    client.repository.ModelMetaNames.AUTHOR_EMAIL:"rahulpro@pro.com",
    client.repository.ModelMetaNames.NAME:"classifier"
}

# %%
#storing the model that gives the high efficiency in repository ( here KNN got the highest priority hence it will taken into consideration)
modelartifact=client.repository.store_model(knn,meta_props=modelprop)

# %%
#get the model id for the stored model
published_model_uid=client.repository.get_model_uid(modelartifact)

# %%
#deploys the model that we have selected
create_dep=client.deployments.create(published_model_uid,name="knearestneighbours")
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '319f8a79-9336-43a1-938b-d1c1af3f844f' started
#
# #######################################################################################
#
#
# INITIALIZING
# DEPLOY_SUCCESS
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='217ccec7-e841-49d5-a9ad-13f76daa887b'
# ------------------------------------------------------------------------------------------------

# %%
#getting an url for using it as API in other applications
scoring_enpoint=client.deployments.get_scoring_url(create_dep)

# %%
scoring_enpoint
# Out:
# 'https://eu-gb.ml.cloud.ibm.com/v3/wml_instances/6e91cd73-52bd-48bb-8f77-247556f30e9d/deployments/217ccec7-e841-49d5-a9ad-13f76daa887b/online'

# %%
knn.predict([])
